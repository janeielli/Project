# %% [markdown]
# <center> Using LSTM to predict Ethereum Price <center>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.layers import LeakyReLU, Dense, Dropout, LSTM
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.optimizers import Adam

# %%
# Loading Ethereum prices into a dataframe

data = pd.read_csv('ETH-USD.csv')
data.head(5)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-10-01  360.309143  369.264404  346.477051  353.205902  353.205902
# 1  2020-10-02  352.949677  354.115417  336.467163  346.238922  346.238922
# 2  2020-10-03  346.218628  351.307709  344.666565  346.522095  346.522095
# 3  2020-10-04  346.602234  354.045746  345.131012  352.579010  352.579010
# 4  2020-10-05  352.736816  355.214081  349.679901  353.956787  353.956787
#
#         Volume
# 0  14679481911
# 1  14215390463
# 2  10060167889
# 3  10696959020
# 4  11809507622

# %%
# Close data of Bitcoin is what we will focus on
close_data = data[['Close']]
close_data.head(5)
# Out:
#         Close
# 0  353.205902
# 1  346.238922
# 2  346.522095
# 3  352.579010
# 4  353.956787

# %%
plt.figure(figsize = (15,9))
plt.plot(data[['Close']])
plt.xticks(range(0, data.shape[0],50), data['Date'].loc[::50],rotation=45)
plt.title("Ethereum Closing Price",fontsize=18, fontweight='bold')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price (USD)',fontsize=18)
plt.show()

# %%
# Normalize values
mms = MinMaxScaler()

n_data = mms.fit_transform(close_data.values)

# %%
# Split data into training and testing

def univariate_data(dataset, start, end, history_size, target_size):
    udata = []
    labels = []

    start = start + history_size
    if end is None:
        end = len(dataset) - target_size

    for i in range(start, end):
        indices = range(i-history_size, i)
        # Reshape data from (history_size,) to (history_size, 1)
        udata.append(np.reshape(dataset[indices], (history_size, 1)))
        labels.append(dataset[i+target_size])
    return np.array(udata), np.array(labels) 

past_history = 5
future_target = 0

train_split = int(len(n_data) * 0.8)

x_train, y_train = univariate_data(n_data,0,train_split,past_history,future_target)

x_test, y_test = univariate_data(n_data,train_split,None,past_history,future_target)

# %%
# Building the model

num_units = 64
learning_rate = 0.0001
activation_function = 'sigmoid'
adam = Adam(learning_rate)
loss_function = 'mse'
batch_size = 5
num_epochs = 100

# Initialize the RNN
model = Sequential()
model.add(LSTM(units = num_units, activation=activation_function, input_shape=(None, 1)))
model.add(LeakyReLU(alpha=0.5))
model.add(Dropout(0.1))
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer=adam, loss=loss_function)

# %%
# Training the model
history = model.fit(x_train,y_train,validation_split=0.1,batch_size=batch_size,epochs=num_epochs,shuffle=False)
# Out:
# Epoch 1/100
# 105/105 [==============================] - 9s 22ms/step - loss: 0.0725 - val_loss: 0.0066
# Epoch 2/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.1068 - val_loss: 0.0042
# Epoch 3/100
# 105/105 [==============================] - 1s 14ms/step - loss: 0.1018 - val_loss: 0.0034
# Epoch 4/100
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0984 - val_loss: 0.0035
# Epoch 5/100
# 105/105 [==============================] - 2s 15ms/step - loss: 0.1088 - val_loss: 0.0037
# Epoch 6/100
# 105/105 [==============================] - 2s 15ms/step - loss: 0.0962 - val_loss: 0.0032
# Epoch 7/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0997 - val_loss: 0.0029
# Epoch 8/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.0940 - val_loss: 0.0029
# Epoch 9/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.0879 - val_loss: 0.0027
# Epoch 10/100
# 105/105 [==============================] - 1s 7ms/step - loss: 0.0846 - val_loss: 0.0028
# Epoch 11/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.0935 - val_loss: 0.0029
# Epoch 12/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0911 - val_loss: 0.0026
# Epoch 13/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0852 - val_loss: 0.0029
# Epoch 14/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0849 - val_loss: 0.0028
# Epoch 15/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0833 - val_loss: 0.0027
# Epoch 16/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0732 - val_loss: 0.0024
# Epoch 17/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0783 - val_loss: 0.0028
# Epoch 18/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0754 - val_loss: 0.0027
# Epoch 19/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0735 - val_loss: 0.0025
# Epoch 20/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0736 - val_loss: 0.0027
# Epoch 21/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0700 - val_loss: 0.0019
# Epoch 22/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0649 - val_loss: 0.0026
# Epoch 23/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0654 - val_loss: 0.0022
# Epoch 24/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0618 - val_loss: 0.0025
# Epoch 25/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0630 - val_loss: 0.0024
# Epoch 26/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0637 - val_loss: 0.0024
# Epoch 27/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0631 - val_loss: 0.0023
# Epoch 28/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0602 - val_loss: 0.0023
# Epoch 29/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0608 - val_loss: 0.0020
# Epoch 30/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0560 - val_loss: 0.0025
# Epoch 31/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0574 - val_loss: 0.0022
# Epoch 32/100
# 105/105 [==============================] - 2s 16ms/step - loss: 0.0572 - val_loss: 0.0017
# Epoch 33/100
# 105/105 [==============================] - 1s 12ms/step - loss: 0.0505 - val_loss: 0.0026
# Epoch 34/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0510 - val_loss: 0.0024
# Epoch 35/100
# 105/105 [==============================] - 1s 12ms/step - loss: 0.0527 - val_loss: 0.0024
# Epoch 36/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0473 - val_loss: 0.0024
# Epoch 37/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.0523 - val_loss: 0.0022
# Epoch 38/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0468 - val_loss: 0.0022
# Epoch 39/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0448 - val_loss: 0.0022
# Epoch 40/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0473 - val_loss: 0.0029
# Epoch 41/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0436 - val_loss: 0.0021
# Epoch 42/100
# 105/105 [==============================] - 1s 13ms/step - loss: 0.0386 - val_loss: 0.0024
# Epoch 43/100
# 105/105 [==============================] - 2s 15ms/step - loss: 0.0407 - val_loss: 0.0035
# Epoch 44/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0421 - val_loss: 0.0025
# Epoch 45/100
# 105/105 [==============================] - 1s 13ms/step - loss: 0.0382 - val_loss: 0.0025
# Epoch 46/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0379 - val_loss: 0.0025
# Epoch 47/100
# 105/105 [==============================] - 1s 13ms/step - loss: 0.0348 - val_loss: 0.0021
# Epoch 48/100
# 105/105 [==============================] - 1s 13ms/step - loss: 0.0374 - val_loss: 0.0026
# Epoch 49/100
# 105/105 [==============================] - 1s 13ms/step - loss: 0.0337 - val_loss: 0.0035
# Epoch 50/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0325 - val_loss: 0.0020
# Epoch 51/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0307 - val_loss: 0.0017
# Epoch 52/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.0280 - val_loss: 0.0024
# Epoch 53/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0295 - val_loss: 0.0035
# Epoch 54/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0285 - val_loss: 0.0034
# Epoch 55/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0251 - val_loss: 0.0019
# Epoch 56/100
# 105/105 [==============================] - 1s 12ms/step - loss: 0.0232 - val_loss: 0.0018
# Epoch 57/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0276 - val_loss: 0.0018
# Epoch 58/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0248 - val_loss: 0.0022
# Epoch 59/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0253 - val_loss: 0.0020
# Epoch 60/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0236 - val_loss: 0.0029
# Epoch 61/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0241 - val_loss: 0.0013
# Epoch 62/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0217 - val_loss: 0.0012
# Epoch 63/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0200 - val_loss: 0.0014
# Epoch 64/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0209 - val_loss: 0.0012
# Epoch 65/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0203 - val_loss: 0.0011
# Epoch 66/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0217 - val_loss: 0.0019
# Epoch 67/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0196 - val_loss: 0.0020
# Epoch 68/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0192 - val_loss: 0.0026
# Epoch 69/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0193 - val_loss: 0.0012
# Epoch 70/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0172 - val_loss: 0.0019
# Epoch 71/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0200 - val_loss: 0.0011
# Epoch 72/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0177 - val_loss: 0.0020
# Epoch 73/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0153 - val_loss: 8.5147e-04
# Epoch 74/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0171 - val_loss: 5.4362e-04
# Epoch 75/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0169 - val_loss: 0.0019
# Epoch 76/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0167 - val_loss: 7.8115e-04
# Epoch 77/100
# 105/105 [==============================] - 2s 15ms/step - loss: 0.0156 - val_loss: 0.0016
# Epoch 78/100
# 105/105 [==============================] - 1s 13ms/step - loss: 0.0146 - val_loss: 7.3855e-04
# Epoch 79/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0142 - val_loss: 7.7063e-04
# Epoch 80/100
# 105/105 [==============================] - 1s 14ms/step - loss: 0.0157 - val_loss: 8.2986e-04
# Epoch 81/100
# 105/105 [==============================] - 1s 14ms/step - loss: 0.0142 - val_loss: 5.3646e-04
# Epoch 82/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0140 - val_loss: 5.9854e-04
# Epoch 83/100
# 105/105 [==============================] - 1s 12ms/step - loss: 0.0142 - val_loss: 0.0011
# Epoch 84/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0137 - val_loss: 0.0011
# Epoch 85/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0136 - val_loss: 5.4696e-04
# Epoch 86/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0127 - val_loss: 0.0018
# Epoch 87/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0141 - val_loss: 8.5022e-04
# Epoch 88/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0129 - val_loss: 5.8206e-04
# Epoch 89/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0128 - val_loss: 8.8958e-04
# Epoch 90/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0138 - val_loss: 0.0016
# Epoch 91/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0109 - val_loss: 9.6706e-04
# Epoch 92/100
# 105/105 [==============================] - 1s 13ms/step - loss: 0.0116 - val_loss: 5.0042e-04
# Epoch 93/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.0111 - val_loss: 7.9154e-04
# Epoch 94/100
# 105/105 [==============================] - 1s 12ms/step - loss: 0.0112 - val_loss: 6.9111e-04
# Epoch 95/100
# 105/105 [==============================] - 2s 15ms/step - loss: 0.0127 - val_loss: 5.1298e-04
# Epoch 96/100
# 105/105 [==============================] - 2s 19ms/step - loss: 0.0113 - val_loss: 0.0012
# Epoch 97/100
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0107 - val_loss: 7.4203e-04
# Epoch 98/100
# 105/105 [==============================] - 1s 14ms/step - loss: 0.0110 - val_loss: 5.6737e-04
# Epoch 99/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.0102 - val_loss: 6.6498e-04
# Epoch 100/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.0108 - val_loss: 5.3364e-04

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(loss))

plt.figure()
plt.plot(epochs, loss,'g',label='Training loss')
plt.plot(epochs, val_loss,'r',label='Validation loss')
plt.title("Training and Validation Loss")
plt.legend()
plt.show()

# %%
original = pd.DataFrame(mms.inverse_transform(y_test))
predictions = pd.DataFrame(mms.inverse_transform(model.predict(x_test)))

ax = sns.lineplot(x=original.index, y=original[0], label="Test Data", color='blue')
ax = sns.lineplot(x=predictions.index, y=predictions[0], label="Prediction", color='red')
ax.set_title('Ethereum Closing Price', size = 14, fontweight='bold')
ax.set_xlabel("Days", size = 14)
ax.set_ylabel("Price (USD)", size = 14)
# Out:
# 5/5 [==============================] - 0s 5ms/step
# Text(0, 0.5, 'Price (USD)')
